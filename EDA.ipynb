# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
# To find the data set is which format.(csv,excel,txt,....)
path=r"C:\Users\HP\Downloads\healthcare_dataset.csv\healthcare_dataset.csv"

# Load csv format
df=pd.read_csv(path)

# Read the data(top 5 rows)
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
# df.isnull() # It return boolean value.
df.isna().sum()  # It return sum of null values for each column.

# Note: If any null values occur inside of the columns.
#    step 1: Either remove those null values (dropna())
#    step 2: or Fill by some any value in place of null by using (mean , median of that column)
#    step 3: Filled by random number before null value of the column or after null value of the column.(ffill,bfill)

# Note: Based on the necessary content you can follow anyone.
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
# To find duplicate values.

df.duplicated().sum()
# Out:
# np.int64(534)

# %%
# remove duplicate records/rows/tuples
df.drop_duplicates(inplace=True) # It properly removed the duplicates on original data set.

# %%
# To check duplicate values.
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# To access only column names

df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
del df['Name']

# %%
del df['Room Number']

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
# To find what are the data types and what is the memory size and count of data types and shape .

df.info()

# Objectives of info method 
# ----------------------------
# 1. To find shape of the data set
# 2. And to find class of the data set.
# 3. To analyze how many null values.(or not null values)
# 4. To display all the column names with data type 
# 5. To display number non null value.
# 6. To analyze what are the numeric columns what are the category columns.
# 7. You can see memory of the data set.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      984 non-null    int64
#  1   Age             984 non-null    int64
#  2   Gender          984 non-null    object
#  3   Condition       984 non-null    object
#  4   Procedure       984 non-null    object
#  5   Cost            984 non-null    int64
#  6   Length_of_Stay  984 non-null    int64
#  7   Readmission     984 non-null    object
#  8   Outcome         984 non-null    object
#  9   Satisfaction    984 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 77.0+ KB

# %%
# to analyze describe of the method. 
# This is the key role of EDA.

df.describe()

# Objectives of describe method
------------------------------
1. To analyze distribution of the data by using std and mean.
     -> Normal distribution (mean ~= meadian)(similar) # meadian is 50% 
     -> right skewed data (mean > median)
     -> Left skewed data. (mean < median)

2. To find lower boundary and upper boundary of box plot.
     -> Q1 ,Q3 ,IQR 

     -> Q1 = 25% , Q3 = 75 % ,IQR = Q3 -Q1 ( It is not a median.)
     lower freq = Q1 - 1.5*IQR  => 35 - 1.5*33 = -14.5
     Upper freq = Q3 + 1.5*IQR  => 68 + 1.5*33 = 117.5
   
  Note : By using these values you can analyze Out layers are extreme points from the data.

    Check the outliers
   -------------------
    -> min ,max =[13,89] -> Age column
    -> boundray range = [-14.5 ,117.5]

  Note : All the minimum and maximum and 25 percentile and 75 percentile and 50 percentile all the values in between boundary ranges
       : That means in Age column We can't find any outliers as per box plot values.

  ->  In Age column there are no outliers You can use box plot values and statistics values.
        statistics values -> by using min and std values.

   Billing amount
---------------------
    lower freq = Q1 - 1.5*IQR  => 13243.718641 - 1.5*(24576.139518000004) = -23620.490636000002
     Upper freq = Q3 + 1.5*IQR  => 37819.858159 + 1.5*(24576.139518000004) = 74684.06743600001

Note : All the minimum and maximum and 25 percentile and 75 percentile and 50 percentile all the values in between boundary ranges
       : That means in Age column We can't find any outliers as per box plot values.

  ->  In Age column there are  outliers when use statistics values.
        statistics values -> by using min and std values.
            beacuse of min value is the negative and std is the positive.
# Out:
#   File <string>:20
#     Note : By using these values you can analyze Out layers are extreme points from the data.
#                                                                                              ^
# IndentationError: unindent does not match any outer indentation level

# %%
37819.858159 + 1.5*(24576.139518000004)
# Out:
# 74684.06743600001

# %%
import matplotlib.pyplot as plt
# Histogram Plot

plt.hist(df['Billing Amount'])
plt.title(' Data distribution of the billing amount')
plt.xlabel(' Billing amount')
plt.ylabel(' Frequency of the amount')
# Out:
# Text(0, 0.5, ' Frequency of the amount')

# %%
# Box plot

plt.boxplot(df['Billing Amount'])
plt.title(' analyize outliers')
# Out:
# Text(0.5, 1.0, ' analyize outliers')

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  54966.000000    54966.000000  54966.000000
# mean      51.535185    25544.306284    301.124404
# std       19.605661    14208.409711    115.223143
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13243.718641    202.000000
# 50%       52.000000    25542.749145    302.000000
# 75%       68.000000    37819.858159    401.000000
# max       89.000000    52764.276736    500.000000

# %%
Note: 1. If the 25 percentile value near to minimum value or
        similar to the minimum value it might possibles to the outliers
      2. If the 75 percentile value near to maximun value or
        similar to the maximum value it might possibles to the outliers .

Note: When you can analyze the count values.
        1. All columns of the count value equal that means your data set has no null value.
        2. the count attribute descibe that only not null values count.

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
num_col=df.select_dtypes(['int','float'])
num_col.head()
# Out:
#    Age  Billing Amount  Room Number
# 0   30    18856.281306          328
# 1   62    33643.327287          265
# 2   76    27955.096079          205
# 3   28    37909.782410          450
# 4   43    14238.317814          458

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54966 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                54966 non-null  object
#  1   Age                 54966 non-null  int64
#  2   Gender              54966 non-null  object
#  3   Blood Type          54966 non-null  object
#  4   Medical Condition   54966 non-null  object
#  5   Date of Admission   54966 non-null  object
#  6   Doctor              54966 non-null  object
#  7   Hospital            54966 non-null  object
#  8   Insurance Provider  54966 non-null  object
#  9   Billing Amount      54966 non-null  float64
#  10  Room Number         54966 non-null  int64
#  11  Admission Type      54966 non-null  object
#  12  Discharge Date      54966 non-null  object
#  13  Medication          54966 non-null  object
#  14  Test Results        54966 non-null  object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
obj_col=df.select_dtypes('object')
obj_col.head()
# Out:
#             Name  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#   Admission Type Discharge Date   Medication  Test Results
# 0         Urgent     2024-02-02  Paracetamol        Normal
# ...

# %%
num_col.head()
# Out:
#    Age  Billing Amount  Room Number
# 0   30    18856.281306          328
# 1   62    33643.327287          265
# 2   76    27955.096079          205
# 3   28    37909.782410          450
# 4   43    14238.317814          458

# %%
del num_col['Room Number']

# %%
num_col.head()
# Out:
#    Age  Billing Amount
# 0   30    18856.281306
# 1   62    33643.327287
# 2   76    27955.096079
# 3   28    37909.782410
# 4   43    14238.317814

# %%
# Distribution of age column.
# Histogram plot
# KDE plot

# %%
# Univariant -> Select single column.
plt.hist(num_col['Age'],bins=20)
plt.title('Distribution of age')
plt.xlabel('Age values')
plt.ylabel('Frequency of age.')
# Out:
# Text(0, 0.5, 'Frequency of age.')

# %%
import seaborn as sns
# Univariant -> Select single column.
sns.kdeplot(num_col['Age'])
plt.title('Distribution of age')
plt.xlabel('Age values')
plt.ylabel('Frequency of age.')
# Out:
# Text(0, 0.5, 'Frequency of age.')

# %%
# Distribution of Billing amount column.

# Univariant -> Select single column.
sns.kdeplot(num_col['Billing Amount'])
plt.title('Distribution of Billing Amount')
plt.xlabel('Billing Amount values')
plt.ylabel('Frequency of Billing Amount.')
# Out:
# Text(0, 0.5, 'Frequency of Billing Amount.')

# %%
# Numeric VS numeric (scatter plot)

# Bivariant -> Select single column.
plt.scatter(num_col['Billing Amount'],num_col['Age'])
plt.title('Distribution of Billing Amount')
plt.xlabel('Billing Amount values')
plt.ylabel('Frequency of Age.')
# Out:
# Text(0, 0.5, 'Frequency of Age.')

# %%
plt.boxplot(num_col['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2153a9b5e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2153a9b60d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2153a9b5d10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2153a9b6350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2153a9b6490>],
#  'means': []}

# %%
plt.boxplot(num_col['Billing Amount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2153a94e850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x215392c3750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2153a94e710>],
#  'medians': [<matplotlib.lines.Line2D at 0x215392516d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21539251810>],
#  'means': []}

# %%
num_col['Status']=num_col['Age'].apply(lambda x: 'Young' if x<30 else ('MidAge' if x<50 else 'OldAge'))
num_col.head()
# Out:
#    Age  Billing Amount  Status
# 0   30    18856.281306  MidAge
# 1   62    33643.327287  OldAge
# 2   76    27955.096079  OldAge
# 3   28    37909.782410   Young
# 4   43    14238.317814  MidAge

# %%
nu_cat=num_col.groupby('Status')['Billing Amount'].mean()
nu_cat
# Out:
# Status
# MidAge    25572.754188
# OldAge    25517.518981
# Young     25577.939837
# Name: Billing Amount, dtype: float64

# %%
nu_cat.plot(kind='bar')
# Out:
# <Axes: xlabel='Status'>

# %%
nu_cat=num_col.groupby('Status')['Billing Amount'].mean()
sns.countplot(nu_cat)
# Out:
# <Axes: xlabel='Status', ylabel='count'>

# %%
obj_col.head()
# Out:
#             Name  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#   Admission Type Discharge Date   Medication  Test Results
# 0         Urgent     2024-02-02  Paracetamol        Normal
# ...

# %%
# Category data type
1. ordinal -> LabelEncoder()
2. nominal -> OneHotEncoder()

# %%
import pandas as pd

# Define the data as a dictionary of lists
data = {
    'Blood Group': ['A+', 'O-', 'B+', 'AB+', 'O+', 'A-'],
    'Gender': ['Female', 'Male', 'Male', 'Female', 'Male', 'Female']
}

# Create the DataFrame
data = pd.DataFrame(data)
data
# Out:
#   Blood Group  Gender
# 0          A+  Female
# 1          O-    Male
# 2          B+    Male
# 3         AB+  Female
# 4          O+    Male
# 5          A-  Female

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
data['Gender_encode']=le.fit_transform(data['Gender'])
data
# Out:
#   Blood Group  Gender  Gender_encode
# 0          A+  Female              0
# 1          O-    Male              1
# 2          B+    Male              1
# 3         AB+  Female              0
# 4          O+    Male              1
# 5          A-  Female              0

# %%
obj_col.head()
# Out:
#             Name  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#   Admission Type Discharge Date   Medication  Test Results
# 0         Urgent     2024-02-02  Paracetamol        Normal
# ...

# %%
df['Admission_Year']=pd.to_datetime(df['Date of Admission']).dt.year
df['Discharge _Year']=pd.to_datetime(df['Discharge Date']).dt.year
df['Staying_days']=(pd.to_datetime(df['Discharge Date'])-pd.to_datetime(df['Date of Admission'])).dt.days
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df['Admission_Year'].value_counts().sort_index()
# Out:
# Admission_Year
# 2019     7300
# 2020    11172
# 2021    10816
# 2022    10915
# 2023    10936
# 2024     3827
# Name: count, dtype: int64

# %%
df['Medical Condition'].value_counts()
# Out:
# Medical Condition
# Arthritis       9218
# Diabetes        9216
# Hypertension    9151
# Obesity         9146
# Cancer          9140
# Asthma          9095
# Name: count, dtype: int64

# %%
df['Admission_Year'].value_counts().sort_index()
# Out:
# Admission_Year
# 2019     7300
# 2020    11172
# 2021    10816
# 2022    10915
# 2023    10936
# 2024     3827
# Name: count, dtype: int64

# %%
# Draw a line plot admission date and number of people's hospitalized specific year.
plt.plot(df['Admission_Year'].value_counts().sort_index().index,df['Admission_Year'].value_counts().sort_index().values,marker='o')

# %%
df['Medical Condition'].head()
# Out:
# 0      Cancer
# 1     Obesity
# 2     Obesity
# 3    Diabetes
# 4      Cancer
# Name: Medical Condition, dtype: object

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df['Hospital'].value_counts()
# Out:
# Hospital
# LLC Smith                       44
# Ltd Smith                       39
# Smith Ltd                       37
# Johnson PLC                     37
# Smith Group                     36
#                                 ..
# James-Owen                       1
# Marks, and Vazquez Jenkins       1
# Sons and Webster                 1
# and Cox, Lawrence Grimes         1
# Thornton and Nguyen Freeman,     1
# Name: count, Length: 39876, dtype: int64

# %%
df[['Medical Condition','Hospital']].groupby(['Medical Condition','Hospital']).value_counts()
# Out:
# Medical Condition  Hospital
# Arthritis          Abbott Inc                     1
#                    Abbott Ltd                     1
#                    Abbott-Castillo                1
#                    Abbott-Martin                  1
#                    Acevedo LLC                    1
#                                                  ..
# Obesity            and Young, Spencer Byrd        1
#                    and Young, Torres Figueroa     2
#                    and Zhang Brooks, Hamilton     1
#                    and Zhang Underwood, Martin    1
#                    and Zimmerman Sons             1
# Name: count, Length: 46184, dtype: int64

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
# blood type 

df['Blood Type'].value_counts()
# Out:
# Blood Type
# A-     6898
# A+     6896
# B+     6885
# AB+    6882
# AB-    6874
# B-     6872
# O+     6855
# O-     6804
# Name: count, dtype: int64

# %%
plt.pie(df['Blood Type'].value_counts().values,labels=df['Blood Type'].value_counts().index,autopct='%0.1f%%')
plt.show()

# %%
df['Status']=num_col['Age'].apply(lambda x: 'Young' if x<30 else ('MidAge' if x<50 else 'OldAge'))

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
import seaborn as sns
sns.countplot(data=df,x='Status',hue='Blood Type')
# Out:
# <Axes: xlabel='Status', ylabel='count'>

# %%
pivot=df.pivot_table(values='Billing Amount',index='Medical Condition',columns='Insurance Provider')
pivot
# Out:
# Insurance Provider         Aetna    Blue Cross         Cigna      Medicare  \
# Medical Condition
# Arthritis           25473.947186  25799.661311  25306.743033  25312.173696
# Asthma              25849.523316  25134.717907  25622.781020  25775.448820
# Cancer              24943.743670  25062.437919  25549.739782  25316.423265
# Diabetes            25549.131042  25826.316623  25676.109981  25711.121719
# Hypertension        25873.862545  25688.533703  24823.156299  25839.634848
# Obesity             25613.903065  26079.991217  26158.570783  25817.376339
#
# Insurance Provider  UnitedHealthcare
# Medical Condition
# Arthritis               25668.944303
# Asthma                  25793.305472
# Cancer                  24882.176385
# Diabetes                25532.861734
# Hypertension            25281.169324
# Obesity                 25331.085166

# %%
    sns.heatmap(pivot.corr(),annot=True,fmt='0.0f')
# Out:
# <Axes: xlabel='Insurance Provider', ylabel='Insurance Provider'>

# %%
sns.heatmap(pivot,annot=True,fmt='0.0f')
# Out:
# <Axes: xlabel='Insurance Provider', ylabel='Medical Condition'>

# %%
heat=sns.heatmap(pivot,annot=True,fmt='0.0f')
plt.imsave(fname='heatmap.png', arr=heat, cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 2
#       1 heat=sns.heatmap(pivot,annot=True,fmt='0.0f')
# ----> 2 plt.imsave(fname='heatmap.png', arr=heat, cmap='viridis')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2620, in imsave(fname, arr, **kwargs)
#    2616 @_copy_docstring_and_deprecators(matplotlib.image.imsave)
#    2617 def imsave(
#    2618     fname: str | os.PathLike | BinaryIO, arr: ArrayLike, **kwargs
#    2619 ) -> None:
# -> 2620     matplotlib.image.imsave(fname, arr, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:1600, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1597 else:
#    1598     # we modify this below, so make a copy (don't modify caller's dict)
#    1599     pil_kwargs = pil_kwargs.copy()
# -> 1600 pil_shape = (rgba.shape[1], rgba.shape[0])
# ...

# %%
p=plt.pie(df['Blood Type'].value_counts().values,labels=df['Blood Type'].value_counts().index,autopct='%0.1f%%')
plt.imshow(fname='imag.png',arr=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 2
#       1 p=plt.pie(df['Blood Type'].value_counts().values,labels=df['Blood Type'].value_counts().index,autopct='%0.1f%%')
# ----> 2 plt.imshow(fname='imag.png',arr=df)
#
# TypeError: imshow() missing 1 required positional argument: 'X'

# %%
p=plt.pie(df['Blood Type'].value_counts().values,labels=df['Blood Type'].value_counts().index,autopct='%0.1f%%')

p
# Out:
# ([<matplotlib.patches.Wedge at 0x2153fa69450>,
# ...
#  [Text(1.0156106293289129, 0.42253408098534445, 'A-'),
#   Text(0.4163150593579975, 1.018175707504234, 'A+'),
#   Text(-0.4278685760331345, 1.013374798208135, 'B+'),
#   Text(-1.019715322196245, 0.41252958885176794, 'AB+'),
#   Text(-1.012393889354774, -0.4301843939488201, 'AB-'),
#   Text(-0.4114220154220194, -1.020162695468759, 'B-'),
#   Text(0.42960591640143175, -1.0126394998186108, 'O+'),
#   Text(1.0178662951122597, -0.41707098349614585, 'O-')],
#  [Text(0.553969434179407, 0.23047313508291511, '12.5%'),
#   Text(0.22708094146799862, 0.555368567729582, '12.5%'),
#   Text(-0.23338285965443697, 0.5527498899317098, '12.5%'),
#   Text(-0.556208357561588, 0.22501613937369158, '12.5%'),
#   Text(-0.5522148487389675, -0.23464603306299275, '12.5%'),
#   Text(-0.22441200841201056, -0.5564523793465957, '12.5%'),
#   Text(0.2343304998553264, -0.5523488180828785, '12.5%'),
#   Text(0.5551997973339597, -0.22749326372517042, '12.4%')])
